# %%
import string
import re
import os
import tempfile
import logging
import csv
import matplotlib.pyplot as plt
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from datetime import datetime
from gensim import corpora
from gensim import models
from gensim.corpora import Dictionary
from collections import namedtuple
import gensim.parsing.preprocessing as processing
from os import listdir
import CustomApi as api
from gensim.models import TfidfModel
#Start Global Variables and Types

#document dir
docs = "../data/documents/"

#Number of topics the model should index
numberOfTopics = 225

#Number of passes the model should make
passes = 75

#Keyphrase tracker
keyphraseTracker = api.KeyWordTracker()

#End Global Variables and Types

# %%
files = listdir(docs+"gt2006/")
entries = []

# %%
for file in files:
    with open(docs+"gt2006/"+file,"rb") as csvfile:
        spamreader = csv.reader(csvfile)
        for row in spamreader:
            if "Authors" not in row[0] and row[15] !='[No abstract available]':
                entries.append(row)

# %%
#title of an abstract
entries[0][1]
# Out:
# 'Proteomic analysis of honeybee worker (Apis mellifera) hypopharyngeal gland development'

# %%
# Create a set of frequent words
stopFile = open("../data/stopwords.txt","r")
stopWords = stopFile.read().splitlines() #This is the copyright symbol, this shows up in every abstract and should not be apart of the corpus
stopWords.extend([u"\u2019",u"\u03bc","bee","bees","honey","honeybee","honeybees",u"\xa9",u"\xc2"])
# for asc in range(97,123):
#     stopWords.extend([chr(asc)])
with open("../data/extraStopWords.txt","r") as extraStopFile:
    stopWords.extend(extraStopFile.read().split("\n"))
# Lowercase each document, split it by white space and filter out stopWords
stopList = set(stopWords)
processing.STOPWORDS = stopList
ps = PorterStemmer()
def removeStops(text):
    stopsRemoved = processing.remove_stopwords(text.lower().translate(None, string.punctuation))
    words = stopsRemoved.split(" ")
    stemmedWords = []
    for w in words:
        if len(ps.stem(w)) > 2:
            stemmedWords.append(ps.stem(w))
    return ' '.join(stemmedWords)
# Each abstract has a 'title':String, 'date':datetime.datetime, 'text':String, and 'keywords':String
abstracts = [api.MyAbstract._make([art[1],datetime.strptime(art[2], '%Y'),removeStops(art[15]), art[16]]) for art in entries]
abstracts.sort(key=lambda q: q.date.year)
entries = None
# Count word frequencies
selections = []

access = lambda x: x.date.year
lastIndex = 0
for i in range(2007,2019):
    index = api.binarySearch(abstracts,i,access)
    if  index != -1:
        selections.append(abstracts[lastIndex:index+1])
        lastIndex = index+1

# %%
from collections import defaultdict
def createCorpus(selection):
    frequency = defaultdict(int)
    for abst in abstracts:
        for token in abst.text.split(" "):
            frequency[token] += 1
    tempFolder = tempfile.gettempdir()
    processedCorpus = [[token for token in abst.text.split(" ") if frequency[token] > 5] for abst in selection]
    dictionary = corpora.Dictionary(processedCorpus)
    dictionary.save(os.path.join(tempFolder,'words.dict'))
    # Create general corpus and serialize in order for it to be iterated over
    corpus = [dictionary.doc2bow(text) for text in processedCorpus]
    corpora.MmCorpus.serialize(os.path.join(tempFolder, 'words.dict'), corpus)
    return api.MyCorpora._make([corpus,dictionary])
    


# Save the dictionary of tokens
# def createModel():
#     tempFolder = tempfile.gettempdir()
#     dictionary = corpora.Dictionary(processedCorpusFor(selection))
#     dictionary.save(os.path.join(tempFolder,'words.dict'))
#     # Create general corpus and serialize in order for it to be iterated over
#     corpus = [dictionary.doc2bow(text) for text in processedCorpus]
#     corpora.MmCorpus.serialize(os.path.join(tempFolder, 'words.dict'), corpus)
    # Train the model and set number of topics

# %%
numTopicsExport = 50

def exportResults(path, sortedVals,wordDict):
    seg = sortedVals[0][0:numTopicsExport]
    #Edges and their weights [(a,b):weight]
    edges = sortedVals[1]
    # set of (a,b)
    exportEdges = set({})
    exportNodes = set({})
    for node in seg:
        exportNodes.add((node["tag"],node["word"],node["occurences"]))
        for e in node["edges"]:
            a = wordDict[e[0]]
            b = wordDict[e[1]]
            if a in seg and b in seg:
                exportEdges.add(e)
                exportNodes.add((a["tag"],a["word"],a["occurences"]))
                exportNodes.add((b["tag"],b["word"],b["occurences"]))
            
    with open(path+"nodes.csv","w") as file:
        file.write("Id,Label,Weight\n")
        for val in exportNodes:
            file.write(str(val[0])+","+val[1].encode('utf8')+','+str(val[2])+'\n')
    with open(path+'edges.csv',"w") as file:
        file.write("Source,Target,Weight\n")
        #We dont want to have duplicate edges written, so we want to make an aedge buffer and then write the buffer
        for e in exportEdges:
            file.write(str(e[0])+","+str(e[1])+","+str(edges[e])+"\n")
#         edgesToWrite = set([])
#         for val in seg:
#             #Edges a node has
#             for edge in val["edges"]:
#                 #Check if (a,b) is an edge else if (b,a) is an edge. The graph is undirected so we dont want duplicates
#                 if edge in edges.keys():
#                     #Edge wasnt in the buffer, add it
#                     if edge not in edgesToWrite:
#                         edgesToWrite.add(edge)
#                 #(b,a) in edge list?
#                 elif (edge[1],edge[0]) in edges.keys():
#                     #edge wasnt in the buffer
#                     edgesToWrite.add(edge)
#         for edge in edgesToWrite:
#             file.write(str(edge[0])+","+str(edge[1])+","+str(edges[edge])+"\n")

# %%
import math as m
def getResults(topics):
    mapper = api.WordMapper()
    #Edges [(a,b):weight]
    edges = {}
    def updateEdgeFreq(vec1):
        if vec1[0] == vec1[1]:
            return None
        altVec = [vec1[1],vec1[0]]
        if vec1 in edges.keys():
            edges[vec1] += 1
            return vec1
        elif altVec in edges.keys():
            edges[altVec] += 1
            return altVec
        else:
            edges[vec1] = 1
            return vec1
    occurences = {}
    topics[len(topics)-1]
    for topic in topics:
        words = topic[0]
        #make all the edges for this topic
        wordEdges = []
        wid = mapper.mapWord(words[0][1])
        for t in words:
            edge = updateEdgeFreq((wid,mapper.mapWord(t[1])))
            if edge != None:
                wordEdges.append(edge)
        #add the edges to each word and and update the number of occurences per word
        for w in words:
            word = w[1]
            wid = mapper.mapWord(word)
            if wid not in occurences.keys():
                occurences[wid] = {"prob":w[0],"occurences":1,"edges":wordEdges, "tag" : wid, "word":word}
            else:
                occurences[wid]["occurences"] += 1
                occurences[wid]["prob"] = max(occurences[wid]["prob"], w[0])
    return [occurences,edges]

# %%
size = 0
start = 0
import os
occurences = None
for i in range(0,len(selections)):
    keyphraseTracker = api.KeyWordTracker()
    size += len(selections[i])
    if size >=50:
        selection = api.flaten(selections[start:i+1])
       
        corpus = createCorpus(selection)
        path = docs+'GephiFiles1/'+str(selection[0].date.year)+'/'
        try:
            os.makedirs(path)
            print "made dirs"
        except:
            #Already exists
            pass
        logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
        tfidf = TfidfModel(corpus.corpus,id2word=corpus.id2word) 
        lda = models.ldamodel.LdaModel(tfidf[corpus.corpus],id2word=corpus.id2word,num_topics=numberOfTopics,passes=passes)
        topics = lda.top_topics(corpus=tfidf[corpus.corpus],dictionary=corpus.id2word,topn=3)
        
        topics.sort(key=lambda k:k[1],reverse=True)
        occurences = getResults(topics)
        sortedVals = [sorted(occurences[0].values(),key=lambda k:k["occurences"],reverse=True),occurences[1]]
        #####Release some of this memory please and thank you
        selection = None
        #occurences = None
        #####
        exportResults(path,sortedVals,occurences[0])
        size = 0
        start = i+1
#for y in keyphraseTracker.topN():
    #print str(y.getPhrase())+", "+str(y.sum())
# Out:
# 2018-06-27 10:14:34,148 : INFO : collecting document frequencies
# 2018-06-27 10:14:34,151 : INFO : PROGRESS: processing document #0
# 2018-06-27 10:14:34,167 : INFO : calculating IDF weights for 533 documents and 5179 features (32217 matrix non-zeros)
# 2018-06-27 10:14:34,200 : INFO : using symmetric alpha at 0.00444444444444
# 2018-06-27 10:14:34,203 : INFO : using symmetric eta at 0.00444444444444
# 2018-06-27 10:14:34,207 : INFO : using serial LDA version on this node
# made dirs
# 2018-06-27 10:14:34,414 : INFO : running online (multi-pass) LDA training, 225 topics, 75 passes over the supplied corpus of 533 documents, updating model once every 533 documents, evaluating perplexity every 533 documents, iterating 50x with a convergence threshold of 0.001000
# C:\Users\hp-pc\Anaconda3\envs\p2\lib\site-packages\gensim\models\ldamodel.py:582: RuntimeWarning: overflow encountered in exp2
#   perwordbound, np.exp2(-perwordbound), len(chunk), corpus_words
# 2018-06-27 10:14:36,477 : INFO : -1425.682 per-word bound, inf perplexity estimate based on a held-out corpus of 533 documents with 3183 words
# 2018-06-27 10:14:36,480 : INFO : PROGRESS: pass 0, at document #533/533
# 2018-06-27 10:14:37,559 : INFO : topic #199 (0.004): 0.015*"nativ" + 0.010*"farm" + 0.010*"domest" + 0.008*"simul" + 0.008*"provid" + 0.006*"current" + 0.006*"dieoff" + 0.006*"predict" + 0.006*"watermelon" + 0.006*"render"
# 2018-06-27 10:14:37,562 : INFO : topic #125 (0.004): 0.014*"cppu" + 0.012*"cry2" + 0.011*"introduct" + 0.008*"queen" + 0.008*"european" + 0.007*"accept" + 0.006*"repress" + 0.006*"african" + 0.006*"transcript" + 0.005*"cucurbita"
# 2018-06-27 10:14:37,565 : INFO : topic #48 (0.004): 0.024*"dsx" + 0.011*"splice" + 0.011*"sexdetermin" + 0.007*"holometabol" + 0.007*"form" + 0.006*"sex" + 0.005*"sexspecif" + 0.004*"moth" + 0.004*"pathway" + 0.004*"sexual"
# 2018-06-27 10:14:37,566 : INFO : topic #93 (0.004): 0.009*"day" + 0.008*"protein" + 0.008*"secret" + 0.007*"fluorid" + 0.007*"entrain" + 0.006*"egg" + 0.006*"express" + 0.006*"stomach" + 0.005*"acid" + 0.005*"rhythm"
# 2018-06-27 10:14:37,569 : INFO : topic #178 (0.004): 0.026*"avocado" + 0.017*"apivar" + 0.008*"amitraz" + 0.008*"board" + 0.007*"varroa" + 0.006*"treat" + 0.006*"follow" + 0.005*"nectar" + 0.005*"bottom" + 0.004*"mite"
# 2018-06-27 10:14:37,578 : INFO : topic diff=213.852768, rho=1.000000
# 2018-06-27 10:14:39,210 : INFO : -35.876 per-word bound, 63057717318.6 perplexity estimate based on a held-out corpus of 533 documents with 3183 words
# 2018-06-27 10:14
perplexity estimate based on a held-out corpus of 533 documents with 3183 words
# 2018-06-27 10:15:45,671 : INFO : PROGRESS: pass 29, at document #533/533
# 2018-06-27 10:15:46,463 : INFO : topic #191 (0.004): 0.015*"gcpoor" + 0.015*"ctermin" + 0.013*"ziziphu" + 0.013*"ntermin" + 0.011*"read" + 0.011*"usag" + 0.010*"gcrich" + 0.010*"amino" + 0.009*"serin" + 0.009*"monodon"
# 2018-06-27 10:15:46,467 : INFO : topic #69 (0.004): 0.021*"espl" + 0.013*"pod" + 0.013*"openpollin" + 0.010*"kgha" + 0.010*"strength" + 0.009*"suh" + 0.009*"russian" + 0.009*"bumbl" + 0.009*"shake" + 0.008*"cage"
# 2018-06-27 10:15:46,470 : INFO : topic #90 (0.004): 0.018*"tor" + 0.012*"eucalyptu" + 0.010*"mimosa" + 0.008*"italian" + 0.008*"veget" + 0.008*"fate" + 0.007*"mrjp" + 0.007*"gst" + 0.007*"type" + 0.007*"complement"
# 2018-06-27 10:15:46,473 : INFO : topic #47 (0.004): 0.023*"drosophila" + 0.022*"melanogast" + 0.022*"tribolium" + 0.019*"gambia" + 0.017*"insectspecif" + 0.016*"castaneum" + 0.014*"anophel" + 0.014*"eukaryot" + 0.013*"mori" + 0.013*"homolog"
# 2018-06-27 10:15:46,474 : INFO : topic #137 (0.004): 0.021*"rex" + 0.017*"qtl" + 0.016*"display" + 0.015*"bumblebe" + 0.014*"invas" + 0.012*"pediculari" + 0.009*"receiv" + 0.009*"ecolog" + 0.009*"avoid" + 0.009*"exagger"
# 2018-06-27 10:15:46,479 : INFO : topic diff=inf, rho=0.179605
# 2018-06-27 10:15:47,654 : INFO : -24.265 per-word bound, 20166242.6 perplexity estimate based on a held-out corpus of 533 documents with 3183 words
# 2018-06-27 10:15:47,663 : INFO : PROGRESS: pass 30, at document #533/533
# 2018-06-27 10:15:48,417 : INFO : topic #90 (0.004): 0.018*"tor" + 0.012*"eucalyptu" + 0.010*"mimosa" + 0.008*"italian" + 0.008*"veget" + 0.008*"fate" + 0.007*"mrjp" + 0.007*"gst" + 0.007*"type" + 0.007*"complement"
# 2018-06-27 10:15:48,418 : INFO : topic #124 (0.004): 0.026*"bursicon" + 0.013*"knot" + 0.012*"project" + 0.009*"dorsal" + 0.008*"languag" + 0.008*"suncompass" + 0.007*"hair" + 0.006*"subesophag" + 0.006*"acquir" + 0.006*"subunit"
# 2018-06-27 10:15:48,434 : INFO : topic #39 (0.004): 0.000*"immunoreact" + 0.000*"hemispher" + 0.000*"thorac" + 0.000*"subdivis" + 0.000*"sog" + 0.000*"protocerebrum" + 0.000*"lip" + 0.000*"ipsilater" + 0.000*"innerv" + 0.000*"actual"
# 2018-06-27 10:15:48,450 : INFO : topic #215 (0.004): 0.013*"sea" + 0.013*"strip" + 0.012*"iran" + 0.011*"provinc" + 0.009*"north" + 0.008*"south" + 0.007*"denatur" + 0.006*"salt" + 0.006*"polyacrylamid" + 0.006*"thorac"
# 2018-06-27 10:15:48,466 : INFO : topic #105 (0.004): 0.024*"lobe" + 0.021*"neuropeptid" + 0.016*"server" + 0.015*"molecul" + 0.013*"algorithm" + 0.013*"optic" + 0.011*"synapt" + 0.010*"messeng" + 0.009*"inject" + 0.009*"host"
# 2018-06-27 10:15:48,487 : INFO : topic diff=inf, rho=0.176777
# 2018-06-27 10:15:50,216 : INFO : -24.250 per-word bound, 19944793.7 perplexity estimate based on a held-out corpus of 533 documents with 3183 words
# 2018-06-27 10:15
# 2018-06-27 11:11:48,039 : INFO : topic #64 (0.004): 0.028*"recombin" + 0.020*"spinosad" + 0.019*"industri" + 0.016*"formul" + 0.014*"background" + 0.013*"oxid" + 0.011*"stress" + 0.010*"mechanist" + 0.010*"repair" + 0.010*"meiotic"
# 2018-06-27 11:11:48,043 : INFO : topic #90 (0.004): 0.022*"vgr" + 0.021*"yeast" + 0.019*"morphophysiolog" + 0.016*"follicular" + 0.014*"identif" + 0.011*"transport" + 0.010*"apic" + 0.009*"vitellogenin" + 0.006*"method" + 0.006*"plasma"
# 2018-06-27 11:11:48,048 : INFO : topic #112 (0.004): 0.049*"springer" + 0.035*"media" + 0.035*"sciencebusi" + 0.032*"llc" + 0.022*"part" + 0.017*"selfmed" + 0.015*"sniffer" + 0.011*"discuss" + 0.010*"herb" + 0.010*"rate"
# 2018-06-27 11:11:48,055 : INFO : topic diff=inf, rho=0.118678
# 2018-06-27 11:11:49,454 : INFO : -25.775 per-word bound, 57423818.4 perplexity estimate based on a held-out corpus of 339 documents with 2172 words
# 2018-06-27 11:11:49,457 : INFO : PROGRESS: pass 70, at document #339/339
# 2018-06-27 11:11:50,252 : INFO : topic #18 (0.004): 0.017*"larva" + 0.016*"nectar" + 0.011*"riparian" + 0.011*"planthopp" + 0.010*"secret" + 0.008*"honeydew" + 0.007*"healthi" + 0.006*"veget" + 0.005*"freshwat" + 0.005*"sporad"
# 2018-06-27 11:11:50,253 : INFO : topic #80 (0.004): 0.022*"glucosid" + 0.022*"cyanogen" + 0.021*"embryo" + 0.013*"day1" + 0.013*"day3" + 0.008*"transcriptom" + 0.008*"stage" + 0.008*"embryon" + 0.008*"embryogenesi" + 0.008*"ingest"
# 2018-06-27 11:11:50,257 : INFO : topic #45 (0.004): 0.021*"obp14" + 0.013*"affin" + 0.013*"biosensor" + 0.013*"eugenol" + 0.013*"wildtyp" + 0.009*"chemic" + 0.008*"bind" + 0.007*"immobil" + 0.007*"mutant" + 0.006*"ligand"
# 2018-06-27 11:11:50,259 : INFO : topic #223 (0.004): 0.018*"maiz" + 0.016*"acarapi" + 0.014*"viz" + 0.014*"diet" + 0.011*"laurel" + 0.011*"band" + 0.011*"corn" + 0.010*"requir" + 0.009*"ingredi" + 0.009*"transgen"
# 2018-06-27 11:11:50,263 : INFO : topic #92 (0.004): 0.029*"epitop" + 0.017*"allergen" + 0.016*"tcell" + 0.014*"api" + 0.007*"beta" + 0.006*"vaccin" + 0.005*"turn" + 0.004*"class" + 0.003*"scrutini" + 0.003*"flexibl"
# 2018-06-27 11:11:50,270 : INFO : topic diff=inf, rho=0.117851
# 2018-06-27 11:11:51,651 : INFO : -25.774 per-word bound, 57379340.3 perplexity estimate based on a held-out corpus of 339 documents with 2172 words
# 2018-06-27 11:11:51,655 : INFO : PROGRESS: pass 71, at document #339/339
# 2018-06-27 11:11:52,421 : INFO : topic #126 (0.004): 0.020*"thymol" + 0.019*"carvacrol" + 0.019*"danc" + 0.015*"complex" + 0.013*"βcd" + 0.011*"mellifer" + 0.009*"plebeia" + 0.009*"bioactiv" + 0.009*"drink" + 0.009*"wax"
perplexity estimate based on a held-out corpus of 339 documents with 2172 words
# 2018-06-27 11:11:56,026 : INFO : PROGRESS: pass 73, at document #339/339
# 2018-06-27 11:11:56,801 : INFO : topic #118 (0.004): 0.027*"floret" + 0.012*"inbr" + 0.012*"variat" + 0.011*"sunflow" + 0.009*"bioindic" + 0.007*"corolla" + 0.007*"depth" + 0.006*"anthesi" + 0.005*"wooden" + 0.005*"polish"
# 2018-06-27 11:11:56,803 : INFO : topic #57 (0.004): 0.000*"anemophil" + 0.000*"subesophag" + 0.000*"extraflor" + 0.000*"etholog" + 0.000*"entomophil" + 0.000*"corrobor" + 0.000*"coast" + 0.000*"longifolia" + 0.000*"uncondit" + 0.000*"nonassoci"
# 2018-06-27 11:11:56,806 : INFO : topic #193 (0.004): 0.021*"vtp" + 0.018*"irrit" + 0.016*"venom" + 0.015*"opsin" + 0.015*"photoreceptor" + 0.011*"mrna" + 0.010*"eye" + 0.010*"extract" + 0.009*"retin" + 0.008*"larva"
# 2018-06-27 11:11:56,811 : INFO : topic #148 (0.004): 0.021*"phenotyp" + 0.016*"gonad" + 0.015*"evolv" + 0.013*"ovari" + 0.010*"dimorph" + 0.008*"massiv" + 0.007*"seen" + 0.006*"strong" + 0.005*"anarchi" + 0.005*"anatom"
# 2018-06-27 11:11:56,813 : INFO : topic #55 (0.004): 0.017*"antenna" + 0.016*"later" + 0.015*"left" + 0.014*"gustatori" + 0.013*"sucros" + 0.010*"antenn" + 0.009*"olfactori" + 0.007*"stimulu" + 0.006*"better" + 0.006*"asymmetri"
# 2018-06-27 11:11:56,822 : INFO : topic diff=inf, rho=0.115470
# 2018-06-27 11:11:58,197 : INFO : -25.765 per-word bound, 57003262.4 perplexity estimate based on a held-out corpus of 339 documents with 2172 words
# 2018-06-27 11:11:58,198 : INFO : PROGRESS: pass 74, at document #339/339
# 2018-06-27 11:11:58,999 : INFO : topic #30 (0.004): 0.030*"plantat" + 0.019*"µgkg" + 0.009*"brood" + 0.009*"rapese" + 0.009*"exceed" + 0.008*"accept" + 0.007*"residu" + 0.005*"255" + 0.005*"hard" + 0.005*"195"
# 2018-06-27 11:11:59,002 : INFO : topic #61 (0.004): 0.020*"sucros" + 0.018*"learn" + 0.016*"condit" + 0.014*"glucos" + 0.014*"reward" + 0.010*"haemolymph" + 0.010*"olfactori" + 0.010*"task" + 0.010*"fructos" + 0.010*"train"
# 2018-06-27 11:11:59,003 : INFO : topic #76 (0.004): 0.000*"anemophil" + 0.000*"subesophag" + 0.000*"extraflor" + 0.000*"etholog" + 0.000*"entomophil" + 0.000*"corrobor" + 0.000*"coast" + 0.000*"longifolia" + 0.000*"uncondit" + 0.000*"nonassoci"
# 2018-06-27 11:11:59,007 : INFO : topic #84 (0.004): 0.021*"mosquito" + 0.019*"esteras" + 0.013*"adulticid" + 0.007*"cc0" + 0.007*"proper" + 0.007*"dedic" + 0.007*"anyon" + 0.007*"otherwis" + 0.007*"law" + 0.006*"detoxif"
# 2018-06-27 11:11:59,009 : INFO : topic #24 (0.004): 0.031*"bqcv" + 0.019*"black" + 0.016*"queen" + 0.014*"capsid" + 0.012*"partial" + 0.011*"sorbitol" + 0.009*"tast" + 0.008*"sensori" + 0.007*"helicas" + 0.007*"nonsynonym"
# 2018-06-27 11:11:59,019 : INFO : topic diff=inf, rho=0.114708

# %% [markdown]
# The above corpus shows the amount of times every word used in the documents is used in every indevidual document. Every word is represented by a token ID, the list of which can be found in "words.dict"
